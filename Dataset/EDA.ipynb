# %% [markdown]
# ## Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
from plotnine import *

# %%
Train=pd.read_csv('cs-training.csv').drop('Unnamed: 0',axis=1)

# %%
Train
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                      1                              0.766127   45
# 1                      0                              0.957151   40
# 2                      0                              0.658180   38
# 3                      0                              0.233810   30
# 4                      0                              0.907239   49
# ...                  ...                                   ...  ...
# 149995                 0                              0.040674   74
# 149996                 0                              0.299745   44
# 149997                 0                              0.246044   58
# 149998                 0                              0.000000   30
# 149999                 0                              0.850283   64
#
#         NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                          2     0.802982         9120.0
# ...

# %%
# Exploratory Data Analysis
var=['RevolvingUtilizationOfUnsecuredLines',
     'age',
     'DebtRatio',
     'MonthlyIncome']
Train[var].describe()
# Out:
#        RevolvingUtilizationOfUnsecuredLines            age      DebtRatio  \
# count                         150000.000000  150000.000000  150000.000000
# mean                               6.048438      52.295207     353.005076
# std                              249.755371      14.771866    2037.818523
# min                                0.000000       0.000000       0.000000
# 25%                                0.029867      41.000000       0.175074
# 50%                                0.154181      52.000000       0.366508
# 75%                                0.559046      63.000000       0.868254
# max                            50708.000000     109.000000  329664.000000
#
#        MonthlyIncome
# count   1.202690e+05
# mean    6.670221e+03
# std     1.438467e+04
# min     0.000000e+00
# 25%     3.400000e+03
# 50%     5.400000e+03
# 75%     8.249000e+03
# max     3.008750e+06

# %%
fig,ax=plt.subplots(2,2,figsize=(20,13))
ax[0,0].hist(Train[var[0]])
ax[0,0].title.set_text(var[0])
ax[0,1].hist(Train[var[1]])
ax[0,1].title.set_text(var[1])
ax[1,0].hist(Train[var[2]])
ax[1,0].title.set_text(var[2])
ax[1,1].hist(Train[var[3]])
ax[1,1].title.set_text(var[3])
#fig.suptitle('Distributions of the four parameters')
fig.savefig('Stats.png')

# %%
cate=['SeriousDlqin2yrs',
      'NumberOfTime30-59DaysPastDueNotWorse',
      'NumberOfOpenCreditLinesAndLoans',
      'NumberOfTimes90DaysLate',
      'NumberRealEstateLoansOrLines',
      'NumberOfTime60-89DaysPastDueNotWorse',
      'NumberOfDependents']

# %%
Train.SeriousDlqin2yrs.value_counts()
# Imply the imbalance of the dataset
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64

# %%
ggplot(Train,aes(x='SeriousDlqin2yrs'))+geom_bar(stat='count')
# Out:
# <ggplot: (-9223372036545534618)>

# %%
ggplot(Train,aes(x=cate[1]))+geom_bar(stat='count')
# Out:
# <ggplot: (-9223372036546378394)>

# %%
ggplot(Train[Train[cate[1]]>1],aes(x=cate[1]))+geom_bar(stat='count')
# Out:
# <ggplot: (-9223372036542954450)>

# %%
ggplot(Train,aes(x=cate[2]))+geom_bar(stat='count')
# Out:
# <ggplot: (-9223372036546359559)>

# %%
ggplot(Train,aes(x=cate[3]))+geom_bar(stat='count')
# Out:
# <ggplot: (310053247)>

# %%
ggplot(Train[Train[cate[3]]>1],aes(x=cate[3]))+geom_bar(stat='count')
# Out:
# <ggplot: (-9223372036545189551)>

# %%
ggplot(Train,aes(x=cate[4]))+geom_bar(stat='count')
# Out:
# <ggplot: (-9223372036545602651)>

# %%
ggplot(Train[Train[cate[4]]>1],aes(x=cate[4]))+geom_bar(stat='count')
# Out:
# <ggplot: (-9223372036531954523)>

# %%
ggplot(Train,aes(x=cate[5]))+geom_bar(stat='count')
# Out:
# <ggplot: (308330332)>

# %%
ggplot(Train[Train[cate[5]]>1],aes(x=cate[5]))+geom_bar(stat='count')
# Out:
# <ggplot: (310285302)>

# %%
ggplot(Train,aes(x=cate[6]))+geom_bar(stat='count')
# Out:
# /Users/lihuayu/anaconda3/lib/python3.7/site-packages/plotnine/layer.py:372: PlotnineWarning: stat_count : Removed 3924 rows containing non-finite values.
# <ggplot: (309162679)>

# %%
import seaborn as sn

# %%
# Correlation hearmap
fig, ax = plt.subplots(figsize=(18,10))   
sn.heatmap(Train.corr(),annot=True)
# Out:
# <AxesSubplot:>
